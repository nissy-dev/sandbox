# %%
import pandas as pd

# %%
df = pd.read_csv("pr_data_cleaned.csv")
df
# Out:
#    number                                              title  \
# 0     168              fix: syntax error in the code example
# 1     186              fix: handle `baseUrl` suffix for GHES
# 2     187  fix: throw helpful error when `query` is used ...
# 3     263                              Update browser import
# 4     265  fix: throw helpful error in case "query", "url...
# 5     281             fix (README): Corrected package import
# 6     314  feat(typescript): expose `type` property for e...
# 7     335  Fix `createAppAuth` arguments `id` to `appId` ...
#
#                                               url            author  \
# 0  https://github.com/octokit/graphql.js/pull/168            lukyth
# 1  https://github.com/octokit/graphql.js/pull/186              gr2m
# 2  https://github.com/octokit/graphql.js/pull/187              gr2m
# 3  https://github.com/octokit/graphql.js/pull/263         domnantas
# 4  https://github.com/octokit/graphql.js/pull/265              gr2m
# ...
